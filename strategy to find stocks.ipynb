# %%
import pandas as pd

# %%
df = pd.read_csv("sec_bhavdata_full_03102022.csv",skipinitialspace=True)

# %%
df.head()
# Out:
#        SYMBOL SERIES        DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0   20MICRONS     EQ  03-Oct-2022       97.75       97.95       98.85
# 1  21STCENMGM     EQ  03-Oct-2022       23.30       22.85       22.85
# 2   3IINFOLTD     EQ  03-Oct-2022       43.85       43.85       44.35
# 3     3MINDIA     EQ  03-Oct-2022    24606.30    24900.00    24900.00
# 4      3PLAND     EQ  03-Oct-2022       16.70       16.00       17.25
#
#    LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  TURNOVER_LACS  \
# 0      95.00       95.30        95.55      96.88        101234          98.08
# 1      22.85       22.85        22.85      22.85          3133           0.72
# 2      43.00       43.60        43.35      43.60        216505          94.40
# 3   23675.05    23990.00     24295.30   24254.16          4824        1170.02
# 4      16.00       17.00        16.80      16.81          5966           1.00
#
#    NO_OF_TRADES DELIV_QTY DELIV_PER
# 0          3911     37382     36.93
# ...

# %%
dir(df)
# Out:
# ['AVG_PRICE',
#  'CLOSE_PRICE',
#  'DATE1',
#  'DELIV_PER',
#  'DELIV_QTY',
#  'HIGH_PRICE',
#  'LAST_PRICE',
#  'LOW_PRICE',
#  'NO_OF_TRADES',
#  'OPEN_PRICE',
#  'PREV_CLOSE',
#  'SERIES',
#  'SYMBOL',
#  'T',
#  'TTL_TRD_QNTY',
#  'TURNOVER_LACS',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
# ...

# %%
df.tail()
# Out:
#          SYMBOL SERIES        DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 2286       ZOTA     EQ  03-Oct-2022      286.00       294.0      294.00
# 2287      ZUARI     EQ  03-Oct-2022      175.15       175.5      178.70
# 2288   ZUARIIND     EQ  03-Oct-2022      164.80       166.0      166.80
# 2289  ZYDUSLIFE     EQ  03-Oct-2022      386.90       388.8      415.05
# 2290  ZYDUSWELL     EQ  03-Oct-2022     1623.80      1623.0     1669.35
#
#       LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  \
# 2286     277.00       282.8       280.65     284.49         16083
# 2287     168.35       171.0       170.05     174.83        168487
# 2288     161.00       163.4       162.10     163.97         21349
# 2289     388.00       409.5       409.35     405.31       8017627
# 2290    1620.15      1650.0      1657.00    1653.51         54879
#
#       TURNOVER_LACS  NO_OF_TRADES DELIV_QTY DELIV_PER
# 2286          45.76           732      7986     49.65
# ...

# %%
df.replace("-","",inplace=True)

# %%
df["STOCK_FILTER"] = df["CLOSE_PRICE"]-df["PREV_CLOSE"]

# %%
required_stocks = df["SYMBOL"][(df.SERIES=="EQ") & (df.DELIV_PER>='90') & (df["STOCK_FILTER"]>0)]

# %%
print(required_stocks)
# Out:
# 149      ARTNIRMAN
# 198     AXISBPSETF
# 243      BBETF0432
# 313          BSHSL
# 401        CPSEETF
# 471         DICIND
# 498     DSPSILVETF
# 516     EBBETF0425
# 600        FINPIPE
# 1191    LICNETFGSC
# 1352     MOQUALITY
# 1483      ONEPOINT
# 1540        PFIZER
# 1770     SDL24BEES
# 1771     SDL26BEES
# 1789     SETUINFRA
# 2156       UMESLTD
# Name: SYMBOL, dtype: object
